# %% [markdown]
# # Add your notebook here
#
# Replace this file with your actual Jupyter notebook (for example, `ssd_single_shot_detector_ship.ipynb`).
#
# This repository is designed as a **notebook-first**, minimal but professional template for SSD (Single Shot Detector) ship detection experiments.
